# %% [markdown]
# <a href="https://colab.research.google.com/github/joni23008/ufo/blob/main/Ryhm%C3%A4_10_Ufo_Havainnot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Tehtävänanto: https://gist.github.com/dipaish/36e59e62e1ef16c0318bd49889d6a848#file-taskdanalysis-md
#
# Järjestele maat esitystä varten,ufo muodot vois olla myös. Vuodet myös mukaan.
# keskiarvot sille miten monta ufo havaintoa on tehty koko datan vuosien aikana keskimääräisesti jne jotai sinnepäin.
# Miten monta ufo havaintoa yhteensä.
# Minä vuosina eniten ja vähiten.
# Esitykseen käytännös 15min max ja kopio slide otsikot grading guidelines.

# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings("ignore")
data = pd.read_csv('/content/ufo-sightings-transformed.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-1-250f26ccd883> in <cell line: 5>()
#       3 import warnings
#       4 warnings.filterwarnings("ignore")
# ----> 5 data = pd.read_csv('/content/ufo-sightings-transformed.csv')
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     209                 else:
#     210                     kwargs[new_arg_name] = new_arg_value
# --> 211             return func(*args, **kwargs)
#     212
#     213         return cast(F, wrapper)
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# ...

# %%
print("Basic overview of the DataFrame.")
print("The first 10 rows of the Pandas DataFrame called data.")
data.head(10)
# Out:
# Basic overview of the DataFrame.
# The first 10 rows of the Pandas DataFrame called data.
#    Unnamed: 0            Date_time date_documented  Year  Month  Hour  Season  \
# 0           0  1949-10-10 20:30:00       4/27/2004  1949     10    20  Autumn
# 1           1  1949-10-10 21:00:00      12/16/2005  1949     10    21  Autumn
# 2           2  1955-10-10 17:00:00       1/21/2008  1955     10    17  Autumn
# 3           3  1956-10-10 21:00:00       1/17/2004  1956     10    21  Autumn
# 4           4  1960-10-10 20:00:00       1/22/2004  1960     10    20  Autumn
# 5           5  1961-10-10 19:00:00       4/27/2007  1961     10    19  Autumn
# 6           6  1965-10-10 21:00:00       2/14/2006  1965     10    21  Autumn
# 7           7  1965-10-10 23:45:00       10/2/1999  1965     10    23  Autumn
# 8           8  1966-10-10 20:00:00       3/19/2009  1966     10    20  Autumn
# 9           9  1966-10-10 21:00:00       5/11/2005  1966     10    21  Autumn
#
# ...

# %%
print("Rows and columns.")
#Return the number of rows only
#data.shape[0]

#Return the number of columns only
#data.shape[1]

#Return both rows and columns
data.shape
# Out:
# Rows and columns.
# (80328, 17)

# %%
print("Return the names of all columns.")
data.columns
# Out:
# Return the names of all columns.
# Index(['Unnamed: 0', 'Date_time', 'date_documented', 'Year', 'Month', 'Hour',
#        'Season', 'Country_Code', 'Country', 'Region', 'Locale', 'latitude',
#        'longitude', 'UFO_shape', 'length_of_encounter_seconds',
#        'Encounter_Duration', 'Description'],
#       dtype='object')

# %%
print("Summary of information like names,data types and missing values.")
data.info()
#Return data types
#data.dtypes
# Out:
# Summary of information like names,data types and missing values.
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 80328 entries, 0 to 80327
# Data columns (total 17 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Unnamed: 0                   80328 non-null  int64
#  1   Date_time                    80328 non-null  object
#  2   date_documented              80328 non-null  object
#  3   Year                         80328 non-null  int64
#  4   Month                        80328 non-null  int64
#  5   Hour                         80328 non-null  int64
#  6   Season                       80328 non-null  object
#  7   Country_Code                 80069 non-null  object
#  8   Country                      80069 non-null  object
#  9   Region                       79762 non-null  object
#  10  Locale                       79871 non-null  object
# ...

# %%
print("Return the index labels that are used.")
data.index
# Out:
# Return the index labels that are used.
# RangeIndex(start=0, stop=80328, step=1)

# %%
missing_count = data.isnull().sum()
print("Return of null values in different data types.")
print(missing_count)
# Out:
# Return of null values in different data types.
# Unnamed: 0                        0
# Date_time                         0
# date_documented                   0
# Year                              0
# Month                             0
# Hour                              0
# Season                            0
# Country_Code                    259
# Country                         259
# Region                          566
# Locale                          457
# latitude                          0
# longitude                         0
# UFO_shape                      1930
# length_of_encounter_seconds       0
# Encounter_Duration                0
# Description                      15
# dtype: int64

# %%
total_data=np.product(data.shape)
total_missing=missing_count.sum()
per_of_missing_data=(total_missing/total_data)*100
print("Return the persentage of missing values.")
print(per_of_missing_data)
# Out:
# Return the persentage of missing values.
# 0.25527689414576704

# %%
# Replace null values with 'Unknown'
print("Replace all null values with Unknown label")
data.fillna('Unknown', inplace=True)
# Out:
# Replace all null values with Unknown label

# %%
print("There are no duplicate values")
data.duplicated()
print("Let's make sure and drop all duplicate calues based on all columns")
data.drop_duplicates()
# Out:
# There are no duplicate values
# Let's make sure and drop all duplicate calues based on all columns
#        Unnamed: 0            Date_time date_documented  Year  Month  Hour  \
# 0               0  1949-10-10 20:30:00       4/27/2004  1949     10    20
# 1               1  1949-10-10 21:00:00      12/16/2005  1949     10    21
# 2               2  1955-10-10 17:00:00       1/21/2008  1955     10    17
# 3               3  1956-10-10 21:00:00       1/17/2004  1956     10    21
# 4               4  1960-10-10 20:00:00       1/22/2004  1960     10    20
# ...           ...                  ...             ...   ...    ...   ...
# 80323       80323  2013-09-09 21:15:00       9/30/2013  2013      9    21
# 80324       80324  2013-09-09 22:00:00       9/30/2013  2013      9    22
# 80325       80325  2013-09-09 22:00:00       9/30/2013  2013      9    22
# 80326       80326  2013-09-09 22:20:00       9/30/2013  2013      9    22
# ...

# %%
#print nominal columns
print("Our nominal columns are --> Season,Country_Code,Country,Region,Locale,latitude,longitude,UFO_shape,Description.")
#print binary columns
print("There are no binary columns in our data.")
#print ordinal columns
print("Our ordinal columns are --> Hour,Month,Year,Encounter_Duration.")
# Out:
# Our nominal columns are --> Season,Country_Code,Country,Region,Locale,latitude,longitude,UFO_shape,Description.
# There are no binary columns in our data.
# Our ordinal columns are --> Hour,Month,Year,Encounter_Duration.

# %%
print("Median for Age:", data['Season'].median())
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/nanops.py in nanmedian(values, axis, skipna, mask)
#     759         try:
# --> 760             values = values.astype("f8")
#     761         except ValueError as err:
#
# ValueError: could not convert string to float: 'Autumn'
#
# The above exception was the direct cause of the following exception:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-17-38454d24ed92> in <cell line: 1>()
# ----> 1 print("Median for Age:", data['Season'].median())
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in median(self, axis, skipna, level, numeric_only, **kwargs)
#   11915             **kwargs,
#   11916         ):
# > 11917             return NDFrame.median(self, axis, skipna, level, numeric_only, **kwargs)
#   11918
# ...
